# %%
#imports
import nibabel as nib
import imageio
import os
import shutil

# %%
#Modified Codes 
#source: https://github.com/alexlaurence/NIfTI-Image-Converter
def convert(inputf):
    inputfile = inputf
    outputfile = "converted/"+inputf



    print('Input file is ', inputfile)
    print('Output folder is ', outputfile)

    # set fn as your 4d nifti file
    image_array = nib.load(inputfile).get_fdata()
    print(len(image_array.shape))

    # ask if rotate
    ask_rotate = 'n'#input('Would you like to rotate the orientation? (y/n) ')

    if ask_rotate.lower() == 'y':
        ask_rotate_num = int(input('OK. By 90° 180° or 270°? '))
        if ask_rotate_num == 90 or ask_rotate_num == 180 or ask_rotate_num == 270:
            print('Got it. Your images will be rotated by {} degrees.'.format(ask_rotate_num))
        else:
            print('You must enter a value that is either 90, 180, or 270. Quitting...')
            sys.exit()
    elif ask_rotate.lower() == 'n':
        print('OK, Your images will be converted it as it is.')
    else:
        print('You must choose either y or n. Quitting...')
        sys.exit()

    # if 4D image inputted
    if len(image_array.shape) == 4:
        # set 4d array dimension values
        nx, ny, nz, nw = image_array.shape

        # set destination folder
        if not os.path.exists(outputfile):
            os.makedirs(outputfile)
            print("Created ouput directory: " + outputfile)

        print('Reading NIfTI file...')

        total_volumes = image_array.shape[3]
        total_slices = image_array.shape[2]

        # iterate through volumes
        for current_volume in range(0, total_volumes):
            slice_counter = 0
            # iterate through slices
            for current_slice in range(0, total_slices):
                if (slice_counter % 1) == 0:
                    # rotate or no rotate
                    if ask_rotate.lower() == 'y':
                        if ask_rotate_num == 90 or ask_rotate_num == 180 or ask_rotate_num == 270:
                            print('Rotating image...')
                            if ask_rotate_num == 90:
                                data = numpy.rot90(image_array[:, :, current_slice, current_volume])
                            elif ask_rotate_num == 180:
                                data = numpy.rot90(numpy.rot90(image_array[:, :, current_slice, current_volume]))
                            elif ask_rotate_num == 270:
                                data = numpy.rot90(numpy.rot90(numpy.rot90(image_array[:, :, current_slice, current_volume])))
                    elif ask_rotate.lower() == 'n':
                        data = image_array[:, :, current_slice, current_volume]
                            
                    #alternate slices and save as png
                    print('Saving image...')
                    image_name = inputfile[:-4] + "_t" + "{:0>3}".format(str(current_volume+1)) + "_z" + "{:0>3}".format(str(current_slice+1))+ ".png"
                    imageio.imwrite(image_name, data)
                    print('Saved.')

                    #move images to folder
                    print('Moving files...')
                    src = image_name
                    shutil.move(src, outputfile)
                    slice_counter += 1
                    print('Moved.')

        print('Finished converting images')

    # else if 3D image inputted
    elif len(image_array.shape) == 3:
        # set 4d array dimension values
        nx, ny, nz = image_array.shape

        # set destination folder
        if not os.path.exists(outputfile):
            os.makedirs(outputfile)
            print("Created ouput directory: " + outputfile)

        print('Reading NIfTI file...')

        total_slices = image_array.shape[2]

        slice_counter = 0
        # iterate through slices
        for current_slice in range(0, total_slices):
            # alternate slices
            if (slice_counter % 1) == 0:
                # rotate or no rotate
                if ask_rotate.lower() == 'y':
                    if ask_rotate_num == 90 or ask_rotate_num == 180 or ask_rotate_num == 270:
                        if ask_rotate_num == 90:
                            data = numpy.rot90(image_array[:, :, current_slice])
                        elif ask_rotate_num == 180:
                            data = numpy.rot90(numpy.rot90(image_array[:, :, current_slice]))
                        elif ask_rotate_num == 270:
                            data = numpy.rot90(numpy.rot90(numpy.rot90(image_array[:, :, current_slice])))
                elif ask_rotate.lower() == 'n':
                    data = image_array[:, :, current_slice]

                #alternate slices and save as png
                if (slice_counter % 1) == 0:
                    print('Saving image...')
                    image_name = inputfile[:-4] + "_z" + "{:0>3}".format(str(current_slice+1))+ ".png"
                    imageio.imwrite(image_name, data)
                    print('Saved.')

                    #move images to folder
                    print('Moving image...')
                    src = image_name
                    shutil.move(src, outputfile)
                    slice_counter += 1
                    print('Moved.')

        print('Finished converting images')
    else:
        print('Not a 3D or 4D Image. Please try again.')

# %%
#Listing out filenames 
paths =[]
for root, dirs, files in os.walk("nii_images"):
    for filename in files:
        #print(filename)
        paths.append(filename)
paths
# Out:
# ['AD_002_S_1018.nii',
#  'AD_005_S_0814.nii',
#  'AD_007_S_1304.nii',
#  'AD_012_S_0689.nii',
#  'AD_018_S_0633.nii',
#  'AD_023_S_1289.nii',
#  'AD_027_S_0404.nii',
#  'AD_136_S_0426.nii']

# %%
for path in paths:
    convert("nii_images/"+path)
# Out:
# <ipython-input-147-5673f39e9b87>:13: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image_array = nib.load(inputfile).get_data()
# Lossy conversion from >f4 to uint8. Range [0.0, 49.58551788330078]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 43.34603500366211]. Convert image to uint8 prior to saving to suppress this warning.
# Input file is  nii_images/AD_002_S_1018.nii
# Output folder is  converted/nii_images/AD_002_S_1018.nii
# 3
# OK, Your images will be converted it as it is.
# Created ouput directory: converted/nii_images/AD_002_S_1018.nii
# Reading NIfTI file...
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 45.18986511230469]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 53.708648681640625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 46.89952850341797]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 59.946590423583984]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 57.75495910644531]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 47.686798095703125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 48.29377746582031]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 84.40338134765625]. Convert image to uint8 prior to saving to suppress this warning.
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 86.35601043701172]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 48.140804290771484]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 50.23881530761719]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 48.800804138183594]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 49.68562316894531]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 47.55345153808594]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 48.32452392578125]. Convert image to uint8 prior to saving to suppress this warning.
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 50.1642951965332]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 51.14816665649414]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 65.63284301757812]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 66.0865249633789]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 112.72074127197266]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 251.5475616455078]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 453.5195617675781]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 521.3163452148438]. Convert image to uint8 prior to saving to suppress this warning.
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 662.8201904296875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 752.0738525390625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 712.0965576171875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 778.8370361328125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 804.4325561523438]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 807.0460815429688]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 733.177978515625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 741.626953125]. Convert image to uint8 prior to saving to suppress this warning.
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 738.0306396484375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 769.753662109375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 766.5931396484375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 818.2613525390625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 798.07568359375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 787.8096313476562]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 804.1693115234375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 906.9584350585938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 994.9151000976562]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 998.8441772460938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1076.3140869140625]. Convert image to uint8 prior to saving to suppress this warning.
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Lossy conversion from >f4 to uint8. Range [0.0, 910.5181274414062]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 955.3782348632812]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 954.4312744140625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1009.894287109375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 977.8642578125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 875.7672729492188]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 926.9931640625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 928.535888671875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1077.7763671875]. Convert image to uint8 prior to saving to suppress this warning.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Lossy conversion from >f4 to uint8. Range [0.0, 854.3851928710938]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 963.3952026367188]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1304.2618408203125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1142.5738525390625]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1161.171630859375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1245.2547607421875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1109.740234375]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1123.5811767578125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1140.38232421875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1130.6151123046875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1130.9559326171875]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1157.8497314453125]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from >f4 to uint8. Range [0.0, 1326.5506591796875]. Convert image to uint8 prior to saving to suppress this warning.
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
# Moving image...
# Moved.
# Saving image...
# Saved.
#